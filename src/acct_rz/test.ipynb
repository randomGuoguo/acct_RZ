# %%
import polars as pl

# %%
blacklist = pl.read_parquet(rf'D:\wise\acct_RZ\data\result\step1_blacklist.parquet')
tracebCK = pl.read_parquet(rf'D:\wise\acct_RZ\data\result\step2_traceback.parquet')
org_bl = pl.read_parquet(rf'D:\wise\acct_RZ\data\result\step3_org_blacklist.parquet')
window_cnt = pl.read_parquet(rf'D:\wise\acct_RZ\data\result\step4_window_counts.parquet')

# %%
window_cnt
# Out:
# shape: (27_371, 11)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ app_dt    ┆ key_type ┆ key_value ┆ default_c ┆ … ┆ default_c ┆ default_c ┆ default_c ┆ default_c │
# │ ---       ┆ ---      ┆ ---       ┆ nt_3m     ┆   ┆ nt_6m_ban ┆ nt_3m_rat ┆ nt_3m_fpd ┆ nt_3m_dpd │
# │ date      ┆ str      ┆ str       ┆ ---       ┆   ┆ k         ┆ e24       ┆ ---       ┆ ---       │
# │           ┆          ┆           ┆ u32       ┆   ┆ ---       ┆ ---       ┆ u32       ┆ u32       │
# │           ┆          ┆           ┆           ┆   ┆ u32       ┆ u32       ┆           ┆           │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2024-03-0 ┆ id       ┆ 1913      ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ 1         ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2024-03-0 ┆ id       ┆ 2630      ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ 1         ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2024-03-0 ┆ id       ┆ 3293      ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ 1         ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2024-03-0 ┆ id       ┆ 3896      ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ 1         ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2024-03-0 ┆ id       ┆ 4367      ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ 1         ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2026-02-2 ┆ pid_id   ┆ 10001713| ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ 8         ┆          ┆ 5140      ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2026-02-2 ┆ pid_id   ┆ 10001875| ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ 8         ┆          ┆ 5626      ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2026-02-2 ┆ pid_id   ┆ 10002093| ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ 8         ┆          ┆ 6280      ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2026-02-2 ┆ pid_id   ┆ 10002272| ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ 8         ┆          ┆ 6816      ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2026-02-2 ┆ pid_id   ┆ 10002777| ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ 8         ┆          ┆ 8332      ┆           ┆   ┆           ┆           ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
